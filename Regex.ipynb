# %%
import re

# %%
my_folder = "C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop
# otes

# %%
my_folder = r"C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop\notes

# %%
result_serch=re.search("pattern","we will see the pattern")

# %%
print(result_serch)
# Out:
# <re.Match object; span=(16, 23), match='pattern'>

# %%
result_serch_2=re.search("pattern","we will see the thing that does no exist in this string")

# %%
print(result_serch_2)
# Out:
# None

# %%
string = r"sara was able to help me find the items i needed quickly"

# %%
corrected_string=re.sub('sara','sarah',string)
print(corrected_string)
# Out:
# sarah was able to help me find the items i needed quickly

# %%
customer_reviews = ['sam was a great help to me in the store', 
                    'the cashier was very rude to me, I think her name was eleanor', 
                    'amazing work from sadeen!', 
                    'sarah was able to help me find the items i needed quickly', 
                    'lucy is such a great addition to the team', 
                    'great service from sara she found me what i wanted'
                   ]

# %%
pattern_to_find=r"sarah?"

# %%
sarah_reviews=[review for review in customer_reviews if re.search(pattern_to_find,review)]

# %%
print(sarah_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
a_pattern=r"^a"

# %%
a_reviews=[review for review in customer_reviews if re.search(a_pattern,review)]

# %%
print(a_reviews)
# Out:
# ['amazing work from sadeen!']

# %%
y_pattern=r'y$'

# %%
y_reviews=[review for review in customer_reviews if re.search(y_pattern,review)]

# %%
print(y_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly']

# %%
need_want_pattern = r"(need|want)ed"

# %%
need_want_reviews=[review for review in customer_reviews if re.search(need_want,review)]

# %%
print(need_want_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
no_punct_pattern=r'[^\w\s]'

# %%
no_punct_reviews=[re.sub(no_punct_pattern,"",review)for review in customer_reviews]

# %%
print(no_punct_reviews)
# Out:
# ['sam was a great help to me in the store', 'the cashier was very rude to me I think her name was eleanor', 'amazing work from sadeen', 'sarah was able to help me find the items i needed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted']
